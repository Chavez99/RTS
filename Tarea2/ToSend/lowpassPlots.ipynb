# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Summaryt4.csv")
df["k"] = np.arange(200)
df.head()
# Out:
#         Raw  Filtered  k
# 0  0.096682  0.019336  0
# 1  0.566589  0.113318  1
# 2  0.868510  0.173702  2
# 3 -0.366821 -0.073364  3
# 4  0.847209  0.169442  4

# %%
# plot two columns using Seaborn with labels and legend
sns.lineplot(data=df[['Raw', 'Filtered']], linewidth=2.5, palette="tab10")
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Title of the plot')
plt.legend(title='Legend', loc='upper right')
